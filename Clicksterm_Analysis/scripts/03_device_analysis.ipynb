# %%
import pandas as pd
events = pd.read_csv("C:\\Users\\sande\\Desktop\\HITESH PROJECT\\data\\clean_web_events.csv")

device_funnel = (
    events.groupby(["device", "event"])
    .size()
    .unstack(fill_value=0)
)

print(device_funnel)
# Out:
# event    add_to_cart  page_view
# device
# desktop            0          2
# mobile             1          2
