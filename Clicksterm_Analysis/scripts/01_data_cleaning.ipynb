# %%
import pandas as pd

# Load data
events = pd.read_csv("C:\\Users\\sande\\Desktop\\HITESH PROJECT\\data\\web_events.csv")
orders = pd.read_csv("C:\\Users\\sande\\Desktop\\HITESH PROJECT\\data\\orders.csv")

# Convert timestamp
events["event_time"] = pd.to_datetime(events["event_time"])

# Remove duplicates
events.drop_duplicates(inplace=True)

# Check missing values
print(events.isnull().sum())

# Save cleaned data
events.to_csv("../data/clean_web_events.csv", index=False)
# Out:
# session_id        0
# user_id           0
# event             0
# page              0
# device            0
# traffic_source    0
# event_time        0
# dtype: int64
